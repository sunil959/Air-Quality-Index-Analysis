# %% [markdown]
# ## Analysis of Air Quality of Calcutta for the year 2016-2020

# %% [markdown]
# ## Importing the CSV file and some libraries

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
csv_path ="./DataSet/Calcutta/Calcutta.csv"

df = pd.read_csv(csv_path, parse_dates= ["Date"])

df.set_index ("Date", inplace = True)

df.head(5)
# Out:
#            Country     City Specie  Value
# Date
# 2016-01-03      IN  Kolkata   pm25  380.7
# 2016-01-04      IN  Kolkata   pm25  314.3
# 2016-01-05      IN  Kolkata   pm25  358.7
# 2016-01-06      IN  Kolkata   pm25  368.3
# 2016-01-07      IN  Kolkata   pm25  428.7

# %%
#Initializing the parameters
pm10 = df[df["Specie"] == "pm10"]
pm25 = df[df["Specie"] == "pm25"]
so2 = df[df["Specie"] == "so2"]
no2 = df[df["Specie"] == "no2"]
o3 = df[df["Specie"] == "o3"]
co = df[df["Specie"] == "co"]

# %% [markdown]
# ## Data representation for PM10:
# This Data represents pm10 for all years i.e. 2016-2020

# %%
import matplotlib.patches as mpatches

def bars_pm10(bars):
    if bars <= 50.0:
        return "good"
    elif bars <= 100.0 :
        return "satisfactory"
    elif bars <=250.0:
        return "moderatley polluted"
    elif bars <= 350.0:
        return "poor"
    elif bars <= 430.0:
        return "very poor" 
    else :
        return "severe"
    
count_pm10 = pm10["Value"].apply(bars_pm10).value_counts().plot(kind = "barh",color=['limegreen',  'sandybrown', 'forestgreen', 'lightcoral',  'indianred', 'maroon'],edgecolor='black',figsize=(10,5))
red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-50 : Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='51-100 : Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='101-250 : Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='251-350 : Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='351-430: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='430+: Severe')

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("PM10 for the years 2016-2020 with parameters")
# Out:
# Text(0.5, 1.0, 'PM10 for the years 2016-2020 with parameters')

# %% [markdown]
# ## Data Representation For PM25:
# This Data represents pm25 for all years i.e. 2016-2020

# %%
def bars_pm25(bars):
    if bars <= 30.0:
        return "good"
    elif bars <= 60.0 :
        return "satisfactory"
    elif bars <= 90.0:
        return "moderatley polluted"
    elif bars <= 120.0:
        return "poor"
    elif bars <= 250.0:
        return "very poor" 
    else :
        return "severe"

count_pm25 = pm25["Value"].apply(bars_pm25).value_counts().plot(kind = "barh",color=[  'indianred','lightcoral','sandybrown', 'maroon', 'limegreen' ],edgecolor='black',figsize=(10,5))
red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-30 : Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='31-60 : Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='61-90 : Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='91-120 : Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='121-250: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='121-250: Severe')

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("PM25 for the years 2016-2020 with parameters")
# Out:
# Text(0.5, 1.0, 'PM25 for the years 2016-2020 with parameters')

# %% [markdown]
# ## Data Representation For SO2:
# This Data represents so2 for all years i.e. 2016-2020

# %%
def bars_so2(bars):
    if bars <= 40.0:
        return "good"
    elif bars <= 80.0 :
        return "satisfactory"
    elif bars <= 380.0:
        return "moderatley polluted"
    elif bars <= 800.0:
        return "poor"
    elif bars <= 1600.0:
        return "very poor" 
    else :
        return "severe"

count_so2 = so2["Value"].apply(bars_so2).value_counts().plot(kind = "barh", color=['forestgreen', 'limegreen','limegreen','sandybrown','lightcoral','forestgreen' ],edgecolor='black',figsize=(10,5))

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-40 : Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='41-80 : Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='81-380 : Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='381-800 : Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='801-1600: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='1600+: Severe')

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("SO2 for the years 2016-2020 with parameters")
# Out:
# Text(0.5, 1.0, 'SO2 for the years 2016-2020 with parameters')

# %% [markdown]
# ## Data Representation For NO2:
# This Data represents no2 for all years i.e. 2016-2020

# %%
def bars_no2(bars):
    if bars <= 40.0:
        return "good"
    elif bars <= 80.0 :
        return "satisfactory"
    elif bars <= 180.0:
        return "moderatley polluted"
    elif bars <= 280.0:
        return "poor"
    elif bars <= 400.0:
        return "very poor" 
    else :
        return "severe"

count_no2 = no2["Value"].apply(bars_no2).value_counts().plot(kind = "barh", color=['forestgreen','limegreen', 'lightcoral', 'sandybrown','maroon' ],edgecolor='black',figsize=(10,5))

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-40: Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='41-80: Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='81-180: Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='181-280: Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='281-400: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='400+: Severe')

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("NO2 for the years 2016-2020 with parameters")
# Out:
# Text(0.5, 1.0, 'NO2 for the years 2016-2020 with parameters')

# %% [markdown]
# ## Data Representation For O3:
# This Data represents o3 for all years i.e. 2016-2020

# %%
def bars_o3(bars):
    if bars <= 50.0:
        return "good"
    elif bars <= 100.0 :
        return "satisfactory"
    elif bars <= 168.0:
        return "moderatley polluted"
    elif bars <= 208.0:
        return "poor"
    elif bars <= 748.0:
        return "very poor" 
    else :
        return "severe"

count_o3 = o3["Value"].apply(bars_o3).value_counts().plot(kind = "barh", color=['forestgreen','limegreen','sandybrown','lightcoral' ],edgecolor='black',figsize=(10,5))

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-50: Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='51-100: Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='101-168: Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='169-208: Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='209-748: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='748+: Severe')

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("O3 for the years 2016-2020 with parameters")
# Out:
# Text(0.5, 1.0, 'O3 for the years 2016-2020 with parameters')

# %% [markdown]
# ## Data Representation For CO:
# This Data represents co for all years i.e. 2016-2020

# %%
def bars_co(bars):
    if bars <= 1.0:
        return "good"
    elif bars <= 2.0 :
        return "satisfactory"
    elif bars <= 10.0:
        return "moderatley polluted"
    elif bars <= 17.0:
        return "poor"
    elif bars <= 34.0:
        return "very poor" 
    else :
        return "severe"

count_co = co["Value"].apply(bars_co).value_counts().plot(kind = "barh", color=['sandybrown', 'lightcoral','indianred','limegreen'],edgecolor='black',figsize=(10,5))

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-1.0: Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='1.1-2.0: Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='2.1-10.0: Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='10.1-17.0: Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='17.0-34.0: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='34.0+: Severe')

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("CO for the years 2016-2020 with parameters")
# Out:
# Text(0.5, 1.0, 'CO for the years 2016-2020 with parameters')

# %% [markdown]
# ## Line graph for PM10 on a yearly basis 2016-2020:

# %%
import matplotlib.patches as mpatches
plt.style.use("seaborn-whitegrid")

pm10_2016 = df["2016"].query('Specie == "pm10"')["Value"].mean()
pm10_2017 = df["2017"].query('Specie == "pm10"')["Value"].mean()
pm10_2018 = df["2018"].query('Specie == "pm10"')["Value"].mean()
pm10_2019 = df["2019"].query('Specie == "pm10"')["Value"].mean()
pm10_2020 = df["2020"].query('Specie == "pm10"')["Value"].mean()

time = [pm10_2016, pm10_2017, pm10_2018, pm10_2019, pm10_2020]
year = ["2016", "2017", "2018", "2019", "2020"]


red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-50 : Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='51-100 : Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='101-250 : Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='251-350 : Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='351-430: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='430+: Severe')

plt.figure(figsize=(10,7))
plt.title("Average value of PM10 for the years 2016-2020")

plt.plot(year, time, color = 'black' , linestyle = '--')


plt.xlabel("Years")
plt.ylabel("Average Value")
#plt.figure(figsize=(20,10))
#plt.figure(year, time, figsize=(20,10))
plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %% [markdown]
# ## Line Graph for PM25 on a yearly basis 2016-2020:

# %%
plt.style.use("seaborn-whitegrid")

pm25_2016 = df["2016"].query('Specie == "pm25"')["Value"].mean()
pm25_2017 = df["2017"].query('Specie == "pm25"')["Value"].mean()
pm25_2018 = df["2018"].query('Specie == "pm25"')["Value"].mean()
pm25_2019 = df["2019"].query('Specie == "pm25"')["Value"].mean()
pm25_2020 = df["2020"].query('Specie == "pm25"')["Value"].mean()

time = [pm25_2016, pm25_2017, pm25_2018, pm25_2019,pm25_2020]
year = ["2016", "2017", "2018", "2019", "2020"]

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-30 : Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='31-60 : Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='61-90 : Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='91-120 : Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='121-250: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='121-250: Severe')

plt.figure(figsize=(10,7))
plt.plot(year, time, color = 'black' , linestyle = '--')

plt.xlabel("Years")
plt.ylabel("Average Count")

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Average value of PM25 for the years 2016-2020")
# Out:
# Text(0.5, 1.0, 'Average value of PM25 for the years 2016-2020')

# %% [markdown]
# ## Line Graph for SO2 on a yearly basis 2016-2020:

# %%
plt.style.use("seaborn-whitegrid")

so2_2016 = df["2016"].query('Specie == "so2"')["Value"].mean()
so2_2017 = df["2017"].query('Specie == "so2"')["Value"].mean()
so2_2018 = df["2018"].query('Specie == "so2"')["Value"].mean()
so2_2019 = df["2019"].query('Specie == "so2"')["Value"].mean()
so2_2020 = df["2020"].query('Specie == "so2"')["Value"].mean()

time = [so2_2016, so2_2017, so2_2018, so2_2019, so2_2020]
year = ["2016", "2017", "2018", "2019", "2020"]

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-40 : Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='41-80 : Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='81-380 : Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='381-800 : Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='801-1600: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='1600+: Severe')

plt.figure(figsize=(10,7))
plt.plot(year, time, color = 'black' , linestyle = '--')

plt.xlabel("Years")
plt.ylabel("Average Count")

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Average value of SO2 for the years 2016-2020")
# Out:
# Text(0.5, 1.0, 'Average value of SO2 for the years 2016-2020')

# %% [markdown]
# ## Line Graph for NO2 on a yearly basis 2016-2020:

# %%
plt.style.use("seaborn-whitegrid")

no2_2016 = df["2016"].query('Specie == "no2"')["Value"].mean()
no2_2017 = df["2017"].query('Specie == "no2"')["Value"].mean()
no2_2018 = df["2018"].query('Specie == "no2"')["Value"].mean()
no2_2019 = df["2019"].query('Specie == "no2"')["Value"].mean()
no2_2020 = df["2020"].query('Specie == "no2"')["Value"].mean()

time = [no2_2016, no2_2017, no2_2018, no2_2019, no2_2020]
year = ["2016", "2017", "2018", "2019", "2020"]

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-40: Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='41-80: Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='81-180: Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='181-280: Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='281-400: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='400+: Severe')

plt.figure(figsize=(10,7))
plt.plot(year, time, color = 'black' , linestyle = '--')

plt.xlabel("Years")
plt.ylabel("Average Count")

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Average value of NO2 for the years 2016-2020")
# Out:
# Text(0.5, 1.0, 'Average value of NO2 for the years 2016-2020')

# %% [markdown]
# ## Line Graph for O3 on a yearly basis 2016-2020:

# %%
plt.style.use("seaborn-whitegrid")

o3_2016 = df["2016"].query('Specie == "o3"')["Value"].mean()
o3_2017 = df["2017"].query('Specie == "o3"')["Value"].mean()
o3_2018 = df["2018"].query('Specie == "o3"')["Value"].mean()
o3_2019 = df["2019"].query('Specie == "o3"')["Value"].mean()
o3_2020 = df["2020"].query('Specie == "o3"')["Value"].mean()

time = [o3_2016, o3_2017, o3_2018, o3_2019, o3_2020]
year = ["2016", "2017", "2018", "2019", "2020"]

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-50: Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='51-100: Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='101-168: Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='169-208: Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='209-748: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='748+: Severe')

plt.figure(figsize=(10,7))
plt.plot(year, time, color = 'black' , linestyle = '--')

plt.xlabel("Years")
plt.ylabel("Average Count")

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Average value of O3 for the years 2016-2020")
# Out:
# Text(0.5, 1.0, 'Average value of O3 for the years 2016-2020')

# %% [markdown]
# ## Line Graph for CO on a yearly basis 2016-2020:

# %%
import matplotlib.patches as mpatches
plt.style.use("seaborn-whitegrid")

co_2016 = df["2016"].query('Specie == "co"')["Value"].mean()
co_2017 = df["2017"].query('Specie == "co"')["Value"].mean()
co_2018 = df["2018"].query('Specie == "co"')["Value"].mean()
co_2019 = df["2019"].query('Specie == "co"')["Value"].mean()
co_2020 = df["2020"].query('Specie == "co"')["Value"].mean()

time = [co_2016, co_2017, co_2018, co_2019, co_2020]
year = ["2016", "2017", "2018", "2019", "2020"]

red_patch1 = mpatches.Patch(color = 'forestgreen', label='0-1.0: Good')
red_patch2 = mpatches.Patch(color = 'limegreen',label='1.1-2.0: Satisfactory')
red_patch3 = mpatches.Patch(color = 'sandybrown', label='2.1-10.0: Moderately Polluted')
red_patch4 = mpatches.Patch(color = 'lightcoral',label='10.1-17.0: Poor')
red_patch5 = mpatches.Patch(color = 'indianred',label='17.1-34.0: Very Poor')
red_patch6 = mpatches.Patch(color = 'maroon',label='34+: Severe')

plt.figure(figsize=(10,7))
plt.plot(year, time, color = 'black' , linestyle = '--')

plt.xlabel("Years")
plt.ylabel("Average Count")

plt.legend(handles=[red_patch1,red_patch2,red_patch3,red_patch4,red_patch5,red_patch6],bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.title("Average value of CO for the years 2016-2020")
# Out:
# Text(0.5, 1.0, 'Average value of CO for the years 2016-2020')
